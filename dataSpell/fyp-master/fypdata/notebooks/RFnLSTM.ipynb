# %% [markdown]
# # Combine Random Forest + LSTM

# %%
# Import libraries
import pandas as pd
from IPython.display import display
import numpy as np
import numpy.random
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.ensemble import RandomForestRegressor

# Load the dataset, only columns date,state,new
df = pd.read_csv('cases_state.csv', usecols=['date', 'state', 'cases_new'])

# Convert 'date' column to datetime format if it's not already
df['date'] = pd.to_datetime(df['date'],  format='%Y-%m-%d')

# Aggregate data by date if you want to plot the total new cases across all states per day
df_grouped = df.groupby('date')['cases_new'].sum().reset_index()

# Check for missing values
print("missing values in dataset: ")
print( df_grouped.isna().sum())

# Fill or drop missing values
df_grouped.fillna(0, inplace=True)

# Plot the total new cases per day
plt.plot(df_grouped['date'], df_grouped['cases_new'])
plt.xlabel('Date')
plt.ylabel('New Cases')
plt.title('Daily New COVID-19 Cases')
plt.xticks(rotation=45) # Rotate x-axis labels for better readability
plt.tight_layout() # Adjust layout to avoid overlap
plt.show()

# Display the aggregated data
display(df_grouped.head(10))

# Get the total number of rows
total_rows = df_grouped.shape[0]
print("Total number of rows:", total_rows)

# sort by date order
df_grouped = df_grouped.sort_values(by='date')

#used to scale data into between 0 and 1
scaler = MinMaxScaler(feature_range=(0, 1))
#drop date columns because it doesn't need to be scaled, just cases_new column only
scaled_data = scaler.fit_transform(df_grouped.drop(['date'], axis=1))

# Scaled data (Numpy array) is converted back into dataframe 
df_grouped_scaled = pd.DataFrame(scaled_data, columns=df_grouped.columns[1:])

#original 'date' is added back into new data frame 
df_grouped_scaled['date'] = df_grouped['date'].values

# Prepare the data for Random Forest
# Here we'll use a windowing technique similar to LSTM, but we need to reshape the data differently.
# We will create features for the last N days for predicting the current day's cases_new.

def create_features(data, target_col='cases_new', sequence_length=30):
    X = []
    y = []
    for i in range(sequence_length, len(data)):
        X.append(data[i-sequence_length:i])  # Last N days
        y.append(data[i][0])  # Current day's cases_new
    return np.array(X), np.array(y)

# Prepare the data for Random Forest model
data_for_rf = df_grouped_scaled.drop(['date'], axis=1).values
X, y = create_features(data_for_rf)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X.reshape(X.shape[0], -1), y, train_size=0.7, shuffle=False)

# Initialize the model
rf_regressor = RandomForestRegressor(n_estimators=100, random_state=42)# check balik berapa/apa itu banyak random state ?
rf_regressor.fit(X_train, y_train)# Train the model
y_pred = rf_regressor.predict(X_test)# Make predictions

# Calculate MAE and RMSE
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)

print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Squared Error (MSE): {mse}")
print(f"Root Mean Squared Error (MSE): {rmse}")

# plot the graph for the 
plt.figure(figsize=(20, 6))
plt.plot(y_test, color='blue', label='Actual Cases')
plt.plot(y_pred, color='red', label='Predicted Cases')
plt.title('COVID-19 Cases Prediction')
plt.xlabel('Time')
plt.ylabel('Cases')
# # Formatting x-axis to show years
# plt.gca().xaxis.set_major_locator(mdates.YearLocator())  # Place ticks every year
# plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))  # Format ticks to show year only
plt.legend()
plt.show()
# Out:
# missing values in dataset:
# date         0
# cases_new    0
# dtype: int64
#         date  cases_new
# 0 2020-01-25          4
# 1 2020-01-26          0
# 2 2020-01-27          0
# 3 2020-01-28          0
# 4 2020-01-29          3
# 5 2020-01-30          1
# 6 2020-01-31          0
# 7 2020-02-01          0
# 8 2020-02-02          0
# 9 2020-02-03          0
# Total number of rows: 1716
# Mean Absolute Error (MAE): 0.002518139507257577
# Mean Squared Error (MSE): 2.910490533374295e-05
# Root Mean Squared Error (MSE): 0.005394896230118143

# %%
# Step 1: Generate sliding windows for the full dataset
def create_sliding_windows_flat(data, sequence_length=30):
    X = []
    for i in range(sequence_length, len(data)):
        # Flatten each sliding window into a 1D array
        X.append(data[i-sequence_length:i].flatten())  # Flatten to 1D array
    return np.array(X)

# Create the sliding window input for the entire dataset
X_rf_full = create_sliding_windows_flat(data_for_rf, sequence_length=30)

# Step 2: Predict using the Random Forest model
rf_full_predictions = rf_regressor.predict(X_rf_full)

# Step 3: Add RF predictions as a new feature to the scaled dataset
# Since the first 30 rows cannot be predicted, fill them with 0 (or NaN if you prefer)
rf_predictions_full = np.append([0] * 30, rf_full_predictions)

# Add the RF predictions to the scaled dataset
# df_grouped_scaled['rf_predictions'] = rf_predictions_full
df_grouped_scaled['rf_predictions'] = scaler.fit_transform(df_grouped_scaled[['rf_predictions']])

# %%
# Updated create_features function
def create_features_with_rf(data, sequence_length=30):
    X = []
    y = []
    for i in range(sequence_length, len(data)):
        # Use all columns (cases_new and rf_predictions) as features
        X.append(data[i-sequence_length:i, :])  # Last N days of all features
        y.append(data[i, 0])  # Predict cases_new (first column)
    return np.array(X), np.array(y)

# Prepare the new input dataset with RF predictions
data_for_lstm = df_grouped_scaled[['cases_new', 'rf_predictions']].values
X_lstm, y_lstm = create_features_with_rf(data_for_lstm)

# Split the dataset into training and testing sets
X_train_lstm, X_test_lstm, y_train_lstm, y_test_lstm = train_test_split(X_lstm, y_lstm, train_size=0.7, shuffle=False)

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dropout, Dense

# Define the LSTM model
model = Sequential()
model.add(LSTM(units=128, return_sequences=True, input_shape=(X_train_lstm.shape[1], X_train_lstm.shape[2])))
model.add(Dropout(0.2))
model.add(LSTM(units=128, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(units=1))  # Output layer for predicting cases_new

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
# history = model.fit(X_train_lstm, y_train_lstm, epochs=100, batch_size=32, validation_split=0.2, shuffle=False)
from keras.callbacks import EarlyStopping
es = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)
history = model.fit(X_train_lstm, y_train_lstm, epochs=200, batch_size=32, validation_split=0.2, callbacks=[es])
# Out:
# Epoch 1/200
# 30/30 [==============================] - 2s 40ms/step - loss: 0.0085 - val_loss: 5.5643e-04
# Epoch 2/200
# 30/30 [==============================] - 1s 32ms/step - loss: 0.0030 - val_loss: 1.8670e-04
# Epoch 3/200
# 30/30 [==============================] - 1s 32ms/step - loss: 0.0022 - val_loss: 1.5562e-04
# Epoch 4/200
# 30/30 [==============================] - 1s 37ms/step - loss: 0.0019 - val_loss: 1.4137e-04
# Epoch 5/200
# 30/30 [==============================] - 1s 38ms/step - loss: 0.0026 - val_loss: 1.7761e-04
# Epoch 6/200
# 30/30 [==============================] - 1s 36ms/step - loss: 0.0019 - val_loss: 1.8314e-04
# Epoch 7/200
# 30/30 [==============================] - 1s 37ms/step - loss: 0.0018 - val_loss: 2.1227e-04
# Epoch 8/200
# 30/30 [==============================] - 1s 38ms/step - loss: 0.0018 - val_loss: 1.4566e-04
# Epoch 9/200
# 30/30 [==============================] - 1s 38ms/step - loss: 0.0017 - val_loss: 1.4508e-04
# Epoch 10/200
# 30/30 [==============================] - 1s 38ms/step - loss: 0.0023 - val_loss: 1.8423e-04
# Epoch 11/200
# 30/30 [==============================] - 1s 39ms/step - loss: 0.0018 - val_loss: 2.1403e-04
# Epoch 12/200
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0018 - val_loss: 2.6314e-04
# Epoch 13/200
# 30/30 [==============================] - 1s 41ms/step - loss: 0.0018 - val_loss: 2.4229e-04
# Epoch 14/200
# 30/30 [==============================] - 1s 40ms/step - loss: 0.0016 - val_loss: 2.0899e-04
# Epoch 15/200
# 30/30 [==============================] - 1s 40ms/step - loss: 0.0014 - val_loss: 1.6416e-04
# Epoch 16/200
# 30/30 [==============================] - 1s 42ms/step - loss: 0.0019 - val_loss: 1.4465e-04
# Epoch 17/200
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0018 - val_loss: 1.9113e-04
# Epoch 18/200
# 30/30 [==============================] - 1s 37ms/step - loss: 0.0018 - val_loss: 1.3145e-04
# Epoch 19/200
# 30/30 [==============================] - 1s 36ms/step - loss: 0.0019 - val_loss: 1.5853e-04
# Epoch 20/200
# 30/30 [==============================] - 1s 35ms/step - loss: 0.0018 - val_loss: 1.5329e-04
# Epoch 21/200
# 30/30 [==============================] - 1s 38ms/step - loss: 0.0017 - val_loss: 1.9738e-04
# Epoch 22/200
# 30/30 [==============================] - 1s 35ms/step - loss: 0.0018 - val_loss: 1.3321e-04
# Epoch 23/200
# 30/30 [==============================] - 1s 38ms/step - loss: 0.0017 - val_loss: 1.6003e-04
# Epoch 24/200
# 30/30 [==============================] - 1s 37ms/step - loss: 0.0016 - val_loss: 1.7304e-04
# Epoch 25/200
# 30/30 [==============================] - 1s 36ms/step - loss: 0.0017 - val_loss: 4.0358e-04
# Epoch 26/200
# 30/30 [==============================] - 1s 36ms/step - loss: 0.0015 - val_loss: 1.3719e-04
# Epoch 27/200
# 30/30 [==============================] - 1s 36ms/step - loss: 0.0017 - val_loss: 2.1059e-04
# Epoch 28/200
# 30/30 [==============================] - 2s 54ms/step - loss: 0.0015 - val_loss: 1.3033e-04
# Epoch 29/200
# 30/30 [==============================] - 1s 41ms/step - loss: 0.0017 - val_loss: 2.0090e-04
# Epoch 30/200
# 30/30 [==============================] - 1s 38ms/step - loss: 0.0014 - val_loss: 2.2007e-04
# Epoch 31/200
# 30/30 [==============================] - 1s 41ms/step - loss: 0.0020 - val_loss: 5.6255e-04
# Epoch 32/200
# 30/30 [==============================] - 1s 39ms/step - loss: 0.0017 - val_loss: 1.9036e-04
# Epoch 33/200
# 30/30 [==============================] - 1s 39ms/step - loss: 0.0017 - val_loss: 1.3685e-04
# Epoch 34/200
# 30/30 [==============================] - 1s 38ms/step - loss: 0.0015 - val_loss: 1.2770e-04
# Epoch 35/200
# 30/30 [==============================] - 1s 42ms/step - loss: 0.0016 - val_loss: 1.4328e-04
# Epoch 36/200
# 30/30 [==============================] - 1s 38ms/step - loss: 0.0018 - val_loss: 1.3037e-04
# Epoch 37/200
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0017 - val_loss: 1.2584e-04
# Epoch 38/200
# 30/30 [==============================] - 1s 40ms/step - loss: 0.0015 - val_loss: 1.8107e-04
# Epoch 39/200
# 30/30 [==============================] - 1s 44ms/step - loss: 0.0017 - val_loss: 1.4457e-04
# Epoch 40/200
# 30/30 [==============================] - 1s 40ms/step - loss: 0.0014 - val_loss: 1.2689e-04
# Epoch 41/200
# 30/30 [==============================] - 1s 40ms/step - loss: 0.0016 - val_loss: 1.6965e-04
# Epoch 42/200
# 30/30 [==============================] - 1s 39ms/step - loss: 0.0018 - val_loss: 1.9865e-04
# Epoch 43/200
# 30/30 [==============================] - 1s 41ms/step - loss: 0.0016 - val_loss: 4.2934e-04
# Epoch 44/200
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0014 - val_loss: 2.0243e-04
# Epoch 45/200
# 30/30 [==============================] - 1s 43ms/step - loss: 0.0014 - val_loss: 1.8271e-04
# Epoch 46/200
# 30/30 [==============================] - 1s 39ms/step - loss: 0.0019 - val_loss: 1.5734e-04
# Epoch 47/200
# 30/30 [==============================] - 1s 38ms/step - loss: 0.0016 - val_loss: 1.9108e-04
# Epoch 48/200
# 30/30 [==============================] - 1s 39ms/step - loss: 0.0014 - val_loss: 1.2582e-04
# Epoch 49/200
# 30/30 [==============================] - 1s 39ms/step - loss: 0.0014 - val_loss: 1.5140e-04
# Epoch 50/200
# 30/30 [==============================] - 1s 38ms/step - loss: 0.0015 - val_loss: 1.6146e-04
# Epoch 51/200
# 30/30 [==============================] - 1s 43ms/step - loss: 0.0015 - val_loss: 2.1493e-04
# Epoch 52/200
# 30/30 [==============================] - 1s 41ms/step - loss: 0.0013 - val_loss: 1.1439e-04
# Epoch 53/200
# 30/30 [==============================] - 1s 38ms/step - loss: 0.0015 - val_loss: 1.4908e-04
# Epoch 54/200
# 30/30 [==============================] - 1s 38ms/step - loss: 0.0013 - val_loss: 1.4588e-04
# Epoch 55/200
# 30/30 [==============================] - 2s 54ms/step - loss: 0.0013 - val_loss: 1.3524e-04
# Epoch 56/200
# 30/30 [==============================] - 1s 45ms/step - loss: 0.0013 - val_loss: 1.1320e-04
# Epoch 57/200
# 30/30 [==============================] - 1s 39ms/step - loss: 0.0013 - val_loss: 1.1533e-04
# Epoch 58/200
# 30/30 [==============================] - 1s 38ms/step - loss: 0.0013 - val_loss: 2.1496e-04
# Epoch 59/200
# 30/30 [==============================] - 1s 38ms/step - loss: 0.0013 - val_loss: 1.0479e-04
# Epoch 60/200
# 30/30 [==============================] - 1s 39ms/step - loss: 0.0015 - val_loss: 1.5624e-04
# Epoch 61/200
# 30/30 [==============================] - 1s 39ms/step - loss: 0.0011 - val_loss: 1.0393e-04
# Epoch 62/200
# 30/30 [==============================] - 1s 43ms/step - loss: 0.0012 - val_loss: 1.0678e-04
# Epoch 63/200
# 30/30 [==============================] - 1s 38ms/step - loss: 0.0013 - val_loss: 1.9500e-04
# Epoch 64/200
# 30/30 [==============================] - 1s 38ms/step - loss: 0.0013 - val_loss: 1.3293e-04
# Epoch 65/200
# Epoch 121/200
# 30/30 [==============================] - 1s 41ms/step - loss: 9.0255e-04 - val_loss: 7.9329e-05
# Epoch 122/200
# 30/30 [==============================] - 1s 48ms/step - loss: 7.8063e-04 - val_loss: 6.9687e-05
# Epoch 123/200
# 30/30 [==============================] - 1s 39ms/step - loss: 8.6507e-04 - val_loss: 7.3531e-05
# Epoch 124/200
# 30/30 [==============================] - 1s 40ms/step - loss: 8.0918e-04 - val_loss: 6.6371e-05
# Epoch 125/200
# 30/30 [==============================] - 1s 39ms/step - loss: 7.5953e-04 - val_loss: 6.4501e-05
# Epoch 126/200
# 30/30 [==============================] - 1s 42ms/step - loss: 6.9980e-04 - val_loss: 7.3764e-05
# Epoch 127/200
# 30/30 [==============================] - 1s 39ms/step - loss: 8.0010e-04 - val_loss: 1.3606e-04
# Epoch 128/200
# 30/30 [==============================] - 1s 38ms/step - loss: 8.0303e-04 - val_loss: 1.0643e-04
# Epoch 129/200
# 30/30 [==============================] - 1s 39ms/step - loss: 7.1030e-04 - val_loss: 6.7518e-05
# Epoch 130/200
# 30/30 [==============================] - 1s 42ms/step - loss: 8.6893e-04 - val_loss: 7.0268e-05

# %%
# Predict using the LSTM model
lstm_predictions = model.predict(X_test_lstm)

# Rescale the predictions back to the original scale
lstm_predictions_rescaled = scaler.inverse_transform(np.concatenate((lstm_predictions, np.zeros((lstm_predictions.shape[0], 1))), axis=1))[:, 0]
y_test_rescaled = scaler.inverse_transform(np.concatenate((y_test_lstm.reshape(-1, 1), np.zeros((y_test_lstm.shape[0], 1))), axis=1))[:, 0]

# Calculate evaluation metrics
mae = mean_absolute_error(y_test_rescaled, lstm_predictions_rescaled)
mse = mean_squared_error(y_test_rescaled, lstm_predictions_rescaled)
rmse = np.sqrt(mse)

print(f"Hybrid Model - Mean Absolute Error (MAE): {mae}")
print(f"Hybrid Model - Mean Squared Error (MSE): {mse}")
print(f"Hybrid Model - Root Mean Squared Error (RMSE): {rmse}")

# Plot predictions vs actual values
plt.figure(figsize=(20, 6))
plt.plot(y_test_rescaled, color='blue', label='Actual Cases')
plt.plot(lstm_predictions_rescaled, color='red', label='Predicted Cases (Hybrid)')
plt.title('Hybrid Model: COVID-19 Cases Prediction')
plt.xlabel('Time')
plt.ylabel('Cases')
plt.legend()
plt.show()
# Out:
# 16/16 [==============================] - 0s 9ms/step
# Hybrid Model - Mean Absolute Error (MAE): 0.0022243845399084372
# Hybrid Model - Mean Squared Error (MSE): 2.28148587899423e-05
# Hybrid Model - Root Mean Squared Error (RMSE): 0.004776490216669799

# %%
# import warnings
# 
# # Save the trained model in HDF5 format
# model.save("hybrid_model.h5")
# 
# #ignore the warning (gives because h5 file)
# warnings.filterwarnings("ignore", category=UserWarning, module='keras.src.engine.training')
# 
# # Save the scaler (if you used one for preprocessing)
# import joblib
# joblib.dump(scaler, "scaler.pkl")

# Save the model in the native Keras format
model.save("hybrid_model.keras")

# %%
import os

# Check if the model file exists
model_path = "hybrid_model.keras"  # Or "hybrid_model.h5"
if os.path.exists(model_path):
    print(f"Model has been successfully saved at {model_path}")
else:
    print("Model saving failed!")
# Out:
# Model has been successfully saved at hybrid_model.keras
